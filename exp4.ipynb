# %%
import os
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestCentroid
from sklearn.metrics import f1_score, classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier

# %%
data_folder = "/content/drive/MyDrive/20newsgroup"

# %%
newsgroups = fetch_20newsgroups(subset='all', data_home=data_folder, remove=('headers', 'footers', 'quotes'))

# %%
X_train, X_test, y_train, y_test = train_test_split(newsgroups.data, newsgroups.target, test_size=0.2, random_state=42)

# %%
# Vectorize the text data using TF-IDF
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# Train a navidebias classifier
naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on the test set
y_pred = rocchio_classifier.predict(X_test_tfidf)

# Calculate the F-score
f_score = f1_score(y_test, y_pred, average='weighted')

# %%
# Make predictions on the test set
y_pred = naive_bayes_classifier.predict(X_test_tfidf)

# Calculate the F-score
f_score = f1_score(y_test, y_pred, average='weighted')

# %%
print("F-score:", f_score)
print(classification_report(y_test, y_pred, target_names=newsgroups.target_names))
# Out:
# F-score: 0.6540311698032364
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.86      0.12      0.21       151
#            comp.graphics       0.70      0.61      0.66       202
#  comp.os.ms-windows.misc       0.67      0.61      0.64       195
# comp.sys.ibm.pc.hardware       0.52      0.78      0.62       183
#    comp.sys.mac.hardware       0.89      0.64      0.74       205
#           comp.windows.x       0.89      0.81      0.85       215
#             misc.forsale       0.86      0.60      0.71       193
#                rec.autos       0.85      0.73      0.79       196
#          rec.motorcycles       0.51      0.74      0.61       168
#       rec.sport.baseball       0.96      0.77      0.86       211
#         rec.sport.hockey       0.88      0.88      0.88       198
#                sci.crypt       0.63      0.83      0.71       201
#          sci.electronics       0.85      0.55      0.67       202
# ...

# %%
#now for knn

# %%
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train_tfidf, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_classifier.predict(X_test_tfidf)
f_score_knn = f1_score(y_test, y_pred_knn, average='weighted')

# %%
print("\nk-Nearest Neighbor F-score:", f_score_knn)
print("k-Nearest Neighbor Classification Report:\n", classification_report(y_test, y_pred_knn, target_names=newsgroups.target_names))
# Out:
# k-Nearest Neighbor F-score: 0.11163314117367769
# k-Nearest Neighbor Classification Report:
#                            precision    recall  f1-score   support
#
#              alt.atheism       0.08      0.17      0.11       151
#            comp.graphics       0.89      0.04      0.08       202
#  comp.os.ms-windows.misc       0.06      0.97      0.11       195
# comp.sys.ibm.pc.hardware       0.89      0.04      0.08       183
#    comp.sys.mac.hardware       1.00      0.03      0.06       205
#           comp.windows.x       1.00      0.07      0.12       215
#             misc.forsale       1.00      0.04      0.08       193
#                rec.autos       0.60      0.02      0.03       196
#          rec.motorcycles       1.00      0.05      0.09       168
#       rec.sport.baseball       1.00      0.09      0.16       211
#         rec.sport.hockey       0.95      0.11      0.19       198
#                sci.crypt       1.00      0.04      0.09       201
# ...

# %%
rocchio_classifier = NearestCentroid()
rocchio_classifier.fit(X_train_tfidf, y_train)
# Out:
# NearestCentroid()

# %%
y_pred_rocchio = rocchio_classifier.predict(X_test_tfidf)
f_score_rocchio = f1_score(y_test, y_pred_rocchio, average='weighted')

# %%
print("\nRocchio F-score:", f_score_rocchio)
print("Rocchio Classification Report:\n", classification_report(y_test, y_pred_rocchio, target_names=newsgroups.target_names))
# Out:
# Rocchio F-score: 0.5843545940524006
# Rocchio Classification Report:
#                            precision    recall  f1-score   support
#
#              alt.atheism       0.35      0.39      0.37       151
#            comp.graphics       0.55      0.57      0.56       202
#  comp.os.ms-windows.misc       0.66      0.57      0.61       195
# comp.sys.ibm.pc.hardware       0.58      0.54      0.56       183
#    comp.sys.mac.hardware       0.80      0.59      0.68       205
#           comp.windows.x       0.87      0.67      0.75       215
#             misc.forsale       0.32      0.73      0.44       193
#                rec.autos       0.76      0.59      0.66       196
#          rec.motorcycles       0.51      0.60      0.55       168
#       rec.sport.baseball       0.65      0.64      0.64       211
#         rec.sport.hockey       0.90      0.67      0.77       198
#                sci.crypt       0.86      0.50      0.63       201
# ...
